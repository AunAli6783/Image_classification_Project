# %% [markdown]
# ### mounting google drive bcz i have uploaded my AI project there and accessing files from there and using them here to train them and show their output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## UNZIPPING FOLDER

# %%
# !unzip AI_Project.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AI_Project/dataset/labels/val/02218.txt
#   inflating: AI_Project/dataset/labels/val/02219.txt
#   inflating: AI_Project/dataset/labels/val/02220.txt
#   inflating: AI_Project/dataset/labels/val/02221.txt
#   inflating: AI_Project/dataset/labels/val/02222.txt
#   inflating: AI_Project/dataset/labels/val/02223.txt
#   inflating: AI_Project/dataset/labels/val/02224.txt
#   inflating: AI_Project/dataset/labels/val/02225.txt
#   inflating: AI_Project/dataset/labels/val/02228.txt
#   inflating: AI_Project/dataset/labels/val/02229.txt
#   inflating: AI_Project/dataset/labels/val/02232.txt
#   inflating: AI_Project/dataset/labels/val/02233.txt
#   inflating: AI_Project/dataset/labels/val/02234.txt
#   inflating: AI_Project/dataset/labels/val/02236.txt
#   inflating: AI_Project/dataset/labels/val/02238.txt
#   inflating: AI_Project/dataset/labels/val/02239.txt
#   inflating: AI_Project/dataset/labels/val/02241.txt
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Installing yolov5 but it is also present in my project folder and installing its requirements

# %%
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/AI_Project /AI_Project/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## training on the v3 model which is less accurate

# %%
# !python detect.py --weights "runs/train/car_detection_model_v3/weights/best.pt" --img 640 --conf 0.1 --source "/content/drive/MyDrive/AI_Project /AI_Project/test_images"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['runs/train/car_detection_model_v3/weights/best.pt'], source=/content/drive/MyDrive/AI_Project /AI_Project/test_images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/AI_Project': No such file or directory
# ...

# %% [markdown]
# traning on the v6 model which is the best model

# %%
# !python detect.py --weights "runs/train/car_detection_model_v6/weights/best.pt" --img 640 --conf 0.1 --source "/content/drive/MyDrive/AI_Project /AI_Project/test_images"
# Out:
# detect: weights=['runs/train/car_detection_model_v6/weights/best.pt'], source=/content/drive/MyDrive/AI_Project /AI_Project/test_images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/AI_Project': No such file or directory
# YOLOv5 🚀 2025-4-27 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7538737 parameters, 0 gradients, 17.4 GFLOPs
# image 1/11 /content/drive/MyDrive/AI_Project /AI_Project/test_images/00001.jpg: 448x640 1 Suzuki Aerio Sedan 2007, 42.3ms
# ...

# %% [markdown]
# training on the best model

# %%
# !python detect.py --weights "runs/train/car_detection_model_v7/weights/best.pt" --img 640 --conf 0.1 --source "/content/drive/MyDrive/AI_Project /AI_Project/test_images"
# Out:
# detect: weights=['runs/train/car_detection_model_v7/weights/best.pt'], source=/content/drive/MyDrive/AI_Project /AI_Project/test_images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/AI_Project': No such file or directory
# YOLOv5 🚀 2025-4-27 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7538737 parameters, 0 gradients, 17.4 GFLOPs
# image 1/13 /content/drive/MyDrive/AI_Project /AI_Project/test_images/00001.jpg: 448x640 1 Suzuki Aerio Sedan 2007, 28.6ms
# ...

# %%
from IPython.display import Image, display
import glob


for image_path in glob.glob('runs/detect/exp18/*.jpg')[:10]:
    display(Image(filename=image_path))

# %% [markdown]
# ## the path to my drive where AI PROJECT is linked/stored

# %%
# !pwd
# Out:
# /content

# %%
cd drive/
# Out:
# /content/drive

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
cd AI_Project /
# Out:
# /content/drive/MyDrive/AI_Project

# %%
cd AI_Project/
# Out:
# /content/drive/MyDrive/AI_Project /AI_Project

# %%
cd yolov5/
# Out:
# /content/drive/MyDrive/AI_Project /AI_Project/yolov5

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...
